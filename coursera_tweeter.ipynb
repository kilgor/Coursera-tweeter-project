# %%
#data analysis libraries
import pandas as pd
import numpy as np

#visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\alice\Desktop\pyton\csv files\covid19_tweets.csv')
df.head()
# Out:
#          user_name         user_location  \
# 0           ᏉᎥ☻լꂅϮ            astroworld
# 1    Tom Basile 🇺🇸          New York, NY
# 2  Time4fisticuffs      Pewee Valley, KY
# 3      ethel mertz  Stuck in the Middle
# 4         DIPR-J&K     Jammu and Kashmir
#
#                                     user_description         user_created  \
# 0  wednesday addams as a disney princess keepin i...  2017-05-26 05:46:42
# 1  Husband, Father, Columnist & Commentator. Auth...  2009-04-16 20:06:23
# 2  #Christian #Catholic #Conservative #Reagan #Re...  2009-02-28 18:57:41
# 3  #Browns #Indians #ClevelandProud #[]_[] #Cavs ...  2019-03-07 01:45:06
# 4  🖊️Official Twitter handle of Department of Inf...  2017-02-12 06:45:15
#
#    user_followers  user_friends  user_favourites  user_verified  \
# 0             624           950            18775          False
# 1            2253          1677               24           True
# 2            9275          9525             7254          False
# ...

# %%
df.head(10)
# Out:
#                            user_name               user_location  \
# 0                             ᏉᎥ☻լꂅϮ                  astroworld
# 1                      Tom Basile 🇺🇸                New York, NY
# 2                    Time4fisticuffs            Pewee Valley, KY
# 3                        ethel mertz        Stuck in the Middle
# 4                           DIPR-J&K           Jammu and Kashmir
# 5                   🎹 Franz Schubert                 Новоро́ссия
# 6                       hr bartender             Gainesville, FL
# 7                     Derbyshire LPC                         NaN
# 8                  Prathamesh Bendre                         NaN
# 9  Member of Christ 🇨🇳🇺🇸🇮🇳🇮🇩🇧🇷🇳🇬🇧🇩🇷🇺  👇🏻location at link below👇🏻
#
#                                     user_description         user_created  \
# 0  wednesday addams as a disney princess keepin i...  2017-05-26 05:46:42
# 1  Husband, Father, Columnist & Commentator. Auth...  2009-04-16 20:06:23
# ...

# %%
#it seems like 'hashtags' column, 'country' column and 'hashtags_parsed' column has NaN values
#lets check the number of NaN values in each column and if they are too many, we can drop them
df.isnull().sum()
# Out:
# user_name               0
# user_location       36771
# user_description    10286
# user_created            0
# user_followers          0
# user_friends            0
# user_favourites         0
# user_verified           0
# date                    0
# text                    0
# source                 77
# is_retweet              0
# dtype: int64

# %%
#lets drop the columns with too many NaN values
df.drop(['hashtags', 'country', 'hashtags_parsed'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 2
#       1 #lets drop the columns with too many NaN values
# ----> 2 df.drop(['hashtags', 'country', 'hashtags_parsed'], axis=1, inplace=True)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
# ...

# %%
df.head()
# Out:
#          user_name         user_location  \
# 0           ᏉᎥ☻լꂅϮ            astroworld
# 1    Tom Basile 🇺🇸          New York, NY
# 2  Time4fisticuffs      Pewee Valley, KY
# 3      ethel mertz  Stuck in the Middle
# 4         DIPR-J&K     Jammu and Kashmir
#
#                                     user_description         user_created  \
# 0  wednesday addams as a disney princess keepin i...  2017-05-26 05:46:42
# 1  Husband, Father, Columnist & Commentator. Auth...  2009-04-16 20:06:23
# 2  #Christian #Catholic #Conservative #Reagan #Re...  2009-02-28 18:57:41
# 3  #Browns #Indians #ClevelandProud #[]_[] #Cavs ...  2019-03-07 01:45:06
# 4  🖊️Official Twitter handle of Department of Inf...  2017-02-12 06:45:15
#
#    user_followers  user_friends  user_favourites  user_verified  \
# 0             624           950            18775          False
# 1            2253          1677               24           True
# 2            9275          9525             7254          False
# ...

# %%
#how can we analyze the data? 
#how many tweets are there in the dataset?

print('Number of tweets in the dataset:', df.shape[0])
# Out:
# Number of tweets in the dataset: 179108

# %%
#first lets find ratio of verified users to unverified users
verified_users = df['user_verified'].value_counts()
print('Number of verified users:', verified_users[1])
print('Number of unverified users:', verified_users[0])

#and make a pie chart
#instead of ture or false we use verified or not verified
plt.figure(figsize=(7,7))
plt.pie(verified_users, labels = ['Verified', 'Not Verified'], autopct='%1.1f%%', startangle=90)
plt.title('Verified vs Unverified Users')
plt.show()
# Out:
# Number of verified users: 23095
# Number of unverified users: 156013
# C:\Users\alice\AppData\Local\Temp\ipykernel_11192\2644852208.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print('Number of verified users:', verified_users[1])
# C:\Users\alice\AppData\Local\Temp\ipykernel_11192\2644852208.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print('Number of unverified users:', verified_users[0])

# %%
#CAN WE İDENTİFY COUNTRİES THAT HAVE THE MOST TWEETS?
#first we need to clean the data
#lets see the unique values in the country column
print(df['user_location'].unique())

#we see that there are some values that are not countries
#lets clean the data
#we will use a dictionary to map the values to countries

country_dict = {
    'United States': 'United States',
    'Washington, DC': 'United States',
    'New York, NY': 'United States',
    'Los Angeles, CA': 'United States',
    'California, USA': 'United States',
    'Chicago, IL': 'United States',
    'Chicago': 'United States',
    'New York': 'United States',
    'California': 'United States',
    'Florida': 'United States',
    'Los Angeles': 'United States',
    'Texas': 'United States',
    'NYC': 'United States',
    'Washington, D.C.': 'United States',
    'Texas, USA': 'United States',
    'Florida, USA': 'United States',
    'Illinois, USA': 'United States',
    'Boston, MA': 'United States',
    'New York City': 'United States',
    'San Francisco': 'United States',
    'Atlanta, GA': 'United States',
    'Seattle': 'United States',
    'Brooklyn, NY': 'United States',
    'San Francisco, CA': 'United States',
    'Seattle, WA': 'United States',
    'Texas, United States': 'United States',
    'Los Angeles, California': 'United States',
    'NY': 'United States',
    'Illinois': 'United States',
    'Boston': 'United States',
    'Atlanta': 'United States',
    'New York, New York': 'United States',
    'California, United States': 'United States',
    'Florida, United States': 'United States',
    'Washington': 'United States',
    'USA': 'United States',
    'United States, United States': 'United States',
    'United States, USA': 'United States',
    'United States, America': 'United States',
    'United States, Earth': 'United States',
    'United States, US': 'United States',
    'United States, US': 'United States',
    
    'United Kingdom': 'United Kingdom',
    'London': 'United Kingdom',
    'England, United Kingdom': 'United Kingdom',
    'England': 'United Kingdom',
    'UK': 'United Kingdom',
    'London, England': 'United Kingdom',
    'United Kingdom, UK': 'United Kingdom',
    'United Kingdom, England': 'United Kingdom',
    'London, UK': 'United Kingdom',
    'London, United Kingdom': 'United Kingdom',
    'England, UK': 'United Kingdom',
    'England, London': 'United Kingdom',
    'United Kingdom, London': 'United Kingdom',
    'United Kingdom, England': 'United Kingdom',
    'United Kingdom, London': 'United Kingdom',
    'United Kingdom, England': 'United Kingdom',
    'United Kingdom, UK': 'United Kingdom',
    'United Kingdom, England': 'United Kingdom',
    'United Kingdom, London': 'United Kingdom',
    'United Kingdom, UK': 'United Kingdom',
    'United Kingdom, England': 'United Kingdom',
    
    
    
    'Canada': 'Canada',
    'Toronto, Ontario': 'Canada',
    
    'India': 'India',
    'Mumbai, India': 'India',
    'New Delhi, India': 'India',
    'India, India': 'India',
    'India, Earth': 'India',
    
    'Australia': 'Australia',
    'Sydney, Australia': 'Australia',
    'Melbourne, Australia': 'Australia',
    'Australia, Australia': 'Australia',

    'South Africa': 'South Africa',
    'Johannesburg, South Africa': 'South Africa',
    'South Africa, South Africa': 'South Africa',
    'South Africa, Africa': 'South Africa',
    
    'Nigeria': 'Nigeria',
    'Lagos, Nigeria': 'Nigeria',
    'Nigeria, Nigeria': 'Nigeria',
    
    'Kenya': 'Kenya',
    'Nairobi, Kenya': 'Kenya',
    'Kenya, Kenya': 'Kenya',
    
    'Ghana': 'Ghana',
    'Accra, Ghana': 'Ghana',
    'Ghana, Ghana': 'Ghana',
    
    'Philippines': 'Philippines',
    'Manila, Philippines': 'Philippines',
    'Philippines, Philippines': 'Philippines',
    
    'Pakistan': 'Pakistan',
    'Karachi, Pakistan': 'Pakistan',
    'Pakistan, Pakistan': 'Pakistan',
    
    'Malaysia': 'Malaysia',
    'Kuala Lumpur, Malaysia': 'Malaysia',
    'Malaysia, Malaysia': 'Malaysia',
    
    'Singapore': 'Singapore',
    'Singapore, Singapore': 'Singapore',
    
    'Indonesia': 'Indonesia',
    'Jakarta, Indonesia': 'Indonesia',
    'Indonesia, Indonesia': 'Indonesia',
    
    'Bangladesh': 'Bangladesh',
    'Dhaka, Bangladesh': 'Bangladesh',
    'Bangladesh, Bangladesh': 'Bangladesh',
    
    'Sri Lanka': 'Sri Lanka',
    'Colombo, Sri Lanka': 'Sri Lanka',
    'Sri Lanka, Sri Lanka': 'Sri Lanka',
    
    'Myanmar': 'Myanmar',
    'Yangon, Myanmar': 'Myanmar',
    
    'Vietnam': 'Vietnam',
    'Hanoi, Vietnam': 'Vietnam',
    
    'Cambodia': 'Cambodia',
    'Phnom Penh, Cambodia': 'Cambodia',
    
    'Thailand': 'Thailand',
    'Bangkok, Thailand': 'Thailand',
    
    'Laos': 'Laos',
    'Vientiane, Laos': 'Laos',
    
    'Brunei': 'Brunei',
    'Bandar Seri Begawan, Brunei': 'Brunei',
    
    'Timor-Leste': 'Timor-Leste',
    'Dili, Timor-Leste': 'Timor-Leste',
    
    'Russia': 'Russia',
    'Moscow, Russia': 'Russia',
    
    'China': 'China',
    'Beijing, China': 'China',
    
    'Japan': 'Japan',
    'Tokyo, Japan': 'Japan',
    
    'South Korea': 'South Korea',
    'Seoul, South Korea': 'South Korea',
    
    'North Korea': 'North Korea',
    
    'Taiwan': 'Taiwan',
    'Taipei, Taiwan': 'Taiwan',
    
    'Hong Kong': 'Hong Kong',
    
    'Mongolia': 'Mongolia',
    'Ulaanbaatar, Mongolia': 'Mongolia',
    
    'Kazakhstan': 'Kazakhstan',
    'Nur-Sultan, Kazakhstan': 'Kazakhstan',
    
    'Uzbekistan': 'Uzbekistan',
    'Tashkent, Uzbekistan': 'Uzbekistan',
    
    
    'Turkey': 'Turkey',
    'Istanbul, Turkey': 'Turkey',
    
    'Iran': 'Iran',
    'Tehran, Iran': 'Iran',
    
    
    'Iraq': 'Iraq',
    'Baghdad, Iraq': 'Iraq',
    
    'Syria': 'Syria',
    'Damascus, Syria': 'Syria',
    
    'Lebanon': 'Lebanon',
    'Beirut, Lebanon': 'Lebanon',
    
}

df['country'] = df['user_location'].map(country_dict)
df['country'].unique()

#now we can find the countries with the most tweets
country_tweets = df['country'].value_counts()
print(country_tweets)

#and make a bar chart
plt.figure(figsize=(10,10))
sns.barplot(x=country_tweets.values, y=country_tweets.index, palette='viridis')
plt.title('Number of Tweets by Country')
plt.xlabel('Number of Tweets')
plt.ylabel('Country')
plt.show()
# Out:
# ['astroworld' 'New York, NY' 'Pewee Valley, KY' ... 'Newton, NJ' 'T.O.'
#  'Aliwal North, South Africa']
# country
# United States     13412
# India              6863
# United Kingdom     5530
# Australia          1601
# Nigeria            1310
# Canada             1303
# South Africa       1259
# Kenya               917
# Philippines         740
# Singapore           466
# Hong Kong           437
# China               338
# Pakistan            302
# Malaysia            302
# Japan               235
# Thailand            235
# Sri Lanka           214
# Ghana               207
# Bangladesh          159
# Lebanon              93
# Turkey               82
# Indonesia            81
# Vietnam              57
# Cambodia             54
# Taiwan               37
# Iraq                 34
# Iran                 19
# Russia               17
# Timor-Leste          15
# Myanmar              13
# Syria                12
# Kazakhstan           11
# South Korea           8
# ...

# %%
df.head()
# Out:
#          user_name         user_location  \
# 0           ᏉᎥ☻լꂅϮ            astroworld
# 1    Tom Basile 🇺🇸          New York, NY
# 2  Time4fisticuffs      Pewee Valley, KY
# 3      ethel mertz  Stuck in the Middle
# 4         DIPR-J&K     Jammu and Kashmir
#
#                                     user_description         user_created  \
# 0  wednesday addams as a disney princess keepin i...  2017-05-26 05:46:42
# 1  Husband, Father, Columnist & Commentator. Auth...  2009-04-16 20:06:23
# 2  #Christian #Catholic #Conservative #Reagan #Re...  2009-02-28 18:57:41
# 3  #Browns #Indians #ClevelandProud #[]_[] #Cavs ...  2019-03-07 01:45:06
# 4  🖊️Official Twitter handle of Department of Inf...  2017-02-12 06:45:15
#
#    user_followers  user_friends  user_favourites  user_verified  \
# 0             624           950            18775          False
# 1            2253          1677               24           True
# 2            9275          9525             7254          False
# ...

# %%
#lets find retweet (is_retweet column) and favorite (user_favourites_count column) counts
'''
retweet_count = df['is_retweet'].value_counts()
print('Number of Retweets:', retweet_count[1])
'''

#it seems like the column is_retweet is not a boolean column, only value is 0 or False
# Out:
# C:\Users\alice\AppData\Local\Temp\ipykernel_11192\3739616256.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print('Number of Retweets:', retweet_count[1])
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[51], line 3
#       1 #lets find retweet (is_retweet column) and favorite (user_favourites_count column) counts
#       2 retweet_count = df['is_retweet'].value_counts()
# ----> 3 print('Number of Retweets:', retweet_count[1])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\series.py:1118, in Series.__getitem__(self, key)
# ...

# %%
# Check unique values in 'is_retweet'
unique_values = df['is_retweet'].unique()
print("Unique values in 'is_retweet':", unique_values)
# Out:
# Unique values in 'is_retweet': [False]

# %%
# Get the counts of True (retweet) and False (original tweet)
retweet_count = df['is_retweet'].value_counts()

# Print the number of retweets (True) and original tweets (False)
print('Number of Retweets:', retweet_count.get(True, 0))
print('Number of Original Tweets:', retweet_count.get(False, 0))
# Out:
# Number of Retweets: 0
# Number of Original Tweets: 179108

# %%
# Sum the 'user_favourites' column to get the total number of favorites (likes)
total_favorites = df['user_favourites'].sum()
print('Total Number of Favorites:', total_favorites)
# Out:
# Total Number of Favorites: 2587054877

# %%
#first drop is_retweet column and check for data again
df.drop('is_retweet', axis=1, inplace=True)
df.head()
# Out:
#          user_name         user_location  \
# 0           ᏉᎥ☻լꂅϮ            astroworld
# 1    Tom Basile 🇺🇸          New York, NY
# 2  Time4fisticuffs      Pewee Valley, KY
# 3      ethel mertz  Stuck in the Middle
# 4         DIPR-J&K     Jammu and Kashmir
#
#                                     user_description         user_created  \
# 0  wednesday addams as a disney princess keepin i...  2017-05-26 05:46:42
# 1  Husband, Father, Columnist & Commentator. Auth...  2009-04-16 20:06:23
# 2  #Christian #Catholic #Conservative #Reagan #Re...  2009-02-28 18:57:41
# 3  #Browns #Indians #ClevelandProud #[]_[] #Cavs ...  2019-03-07 01:45:06
# 4  🖊️Official Twitter handle of Department of Inf...  2017-02-12 06:45:15
#
#    user_followers  user_friends  user_favourites  user_verified  \
# 0             624           950            18775          False
# 1            2253          1677               24           True
# 2            9275          9525             7254          False
# ...

# %%
#lets check dated and in which month the tweets were made in and make a bar chart
#and convert the numbers of months to names of months
df['date'] = pd.to_datetime(df['date'])
df['month'] = df['date'].dt.month_name()
month_tweets = df['month'].value_counts()
print(month_tweets)

plt.figure(figsize=(10,10))
sns.barplot(x=month_tweets.values, y=month_tweets.index, palette='viridis')
plt.title('Number of Tweets by Month')
plt.xlabel('Number of Tweets')
plt.ylabel('Month')
plt.show()
# Out:
# month
# August    127172
# July       51936
# Name: count, dtype: int64
# C:\Users\alice\AppData\Local\Temp\ipykernel_11192\809724525.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=month_tweets.values, y=month_tweets.index, palette='viridis')

# %%
#lets check the number of tweets made by verified users and unverified users
verified_tweets = df[df['user_verified'] == True]['user_verified'].count()
unverified_tweets = df[df['user_verified'] == False]['user_verified'].count()
print('Number of Tweets by Verified Users:', verified_tweets)

print('Number of Tweets by Unverified Users:', unverified_tweets)

#and make a pie chart
plt.figure(figsize=(7,7))
plt.pie([verified_tweets, unverified_tweets], labels = ['Verified', 'Not Verified'], autopct='%1.1f%%', startangle=90)
plt.title('Verified vs Unverified Users')
plt.show()
# Out:
# Number of Tweets by Verified Users: 23095
# Number of Tweets by Unverified Users: 156013
